# %%
import pandas as pd
import numpy  as np
pd.set_option("display.max_rows", None)
file_path = "../bases/formacao.csv"
formacao = pd.read_csv("formacao.csv")

formacao
# Out:
#             date                                             degree  \
# 0    2016 – 2016  Executive Education, Innovation & Entrepreneur...
# 1    2007 – 2010                                          Economics
# 2    2015 – 2015            Master of Business Administration (MBA)
# 3    2009 – 2012                    Bacharel em Design de Ambientes
# 4    2016 – 2019                                  Bachelor’s Degree
# 5    2013 – 2015                                         Technician
# 6    2014 – 2019                       Engenharia de Produção Civil
# 7    2011 – 2016                         Bachelor of Science (B.S.)
# 8    2015 – 2015                         Bachelor of Science (B.S.)
# 9    2011 – 2011    Pós Graduação em Gestão Estratégica de Negócios
# 10   2006 – 2009               Bacharel em Publicidade e Propaganda
# 11   1992 – 1998                                    Master's Degree
# 12   2016 – 2019                             Cursando administração
# ...

# %% [markdown]
# ### Substituindo os dados NaN por não informado

# %%
formacao.fillna('Não informado', inplace=True)

# %%
formacao
# Out:
#             date                                             degree  \
# 0    2016 – 2016  Executive Education, Innovation & Entrepreneur...
# 1    2007 – 2010                                          Economics
# 2    2015 – 2015            Master of Business Administration (MBA)
# 3    2009 – 2012                    Bacharel em Design de Ambientes
# 4    2016 – 2019                                  Bachelor’s Degree
# 5    2013 – 2015                                         Technician
# 6    2014 – 2019                       Engenharia de Produção Civil
# 7    2011 – 2016                         Bachelor of Science (B.S.)
# 8    2015 – 2015                         Bachelor of Science (B.S.)
# 9    2011 – 2011    Pós Graduação em Gestão Estratégica de Negócios
# 10   2006 – 2009               Bacharel em Publicidade e Propaganda
# 11   1992 – 1998                                    Master's Degree
# 12   2016 – 2019                             Cursando administração
# ...
